# %% [markdown]
# # NovaMart Data Exploration
#
# Exploratory notebook — NOT production code. All production code lives in `src/bcgx/`
#
# ---
#
# **Engagement:** BCG X × NovaMart Retail Analytics
# **Author:** BCG X Analytics Team
# **Purpose:** Interactive data exploration and hypothesis development
#
# > ⚠️ This notebook is a scratchpad. Any logic that should persist must be
# > refactored into the `src/bcgx/` package before being used in production.

# %%
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# Display settings
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)
pd.set_option("display.float_format", "{:.4f}".format)
pd.set_option("display.width", 120)

np.set_printoptions(precision=4, suppress=True)

# Paths (relative to repo root)
DATA_RAW = Path("../data/raw")
DATA_PROCESSED = Path("../data/processed")
OUTPUTS = Path("../data/outputs")

print("Environment ready.")
print(f"pandas  : {pd.__version__}")
print(f"numpy   : {np.__version__}")
print(f"data/raw exists: {DATA_RAW.exists()}")
